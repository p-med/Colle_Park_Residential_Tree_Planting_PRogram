# %% [markdown]
# # Residential Tree Planting project data prep

# %% [markdown]
# ## Loading and formatting data

# %%
import pandas as pd
import os
import numpy as np
import geopy

# %%
#Rename excel files
old_names = list(os.listdir())

for i in old_names:
    if 'xlsx' not in i:
        old_names.remove(i)

# %%
new_names = []
for i in old_names:
    new_name = i.lower().replace(" ","_").strip()
    new_name = new_name.replace("casey_", "").replace("tree_","").replace("trees_","").replace("planting_","")
    new_names.append(new_name)

# %%
new_names[1] = 'spring_2023.xlsx'
new_names[2] = 'spring_2024_2.xlsx'
new_names[4] = 'fall_2024.xlsx'
new_names[6] = 'spring_2024_1.xlsx'

new_names
# Out:
# ['fall_2023.xlsx',
#  'spring_2023.xlsx',
#  'spring_2024_2.xlsx',
#  'fall_2025.xlsx',
#  'fall_2024.xlsx',
#  'spring_2025.xlsx',
#  'spring_2024_1.xlsx']

# %%
for i in old_names:
    os.rename(i, new_names[old_names.index(i)])

# %%
# Out:
# 'spring_2023.xlsx'

# %%
# Read files into df
dfs = {}
for i in new_names:
    dfs[i] = pd.read_excel(i, header=0)
# Out:
# C:\Users\pmedina\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
dfs['spring_2023.xlsx']
# Out:
#    Application Date; Planting on Resid Property           Area  District #  \
# 0                           2022-05-14 21:50:25   Daniels Pk E           1
# 1                           2022-11-11 13:10:39   Daniels Pk W           1
# 2                           2023-02-14 11:03:46      Oak Sps W           1
# 3                           2023-02-24 08:53:47    Hollywood E           1
# 4                           2022-05-09 19:33:25      Autoville           1
# 5                           2023-02-17 10:27:18         Berwyn           2
# 6                           2021-12-03 00:00:00  Calvert Hills           3
# 7                           2022-04-30 07:23:56  Calvert Hills           3
# 8                           2022-08-01 23:15:34  CP Est Yarrow           3
# 9                           2022-07-08 20:03:30       CP Woods           4
# 10                          2023-02-03 21:42:58       CP Woods           4
# 11                          2023-02-20 07:44:08       CP Woods           4
# 12                          2023-02-24 08:59:52       CP Woods           4
#
#            First and Last Name:  \
# 0             Kirstin Showalter
# 1                  Anne Tolbert
# 2               Frances Sutphen
# 3                   Donald Hays
# 4                      Alan Hew
# 5                     John Shea
# 6               Janice Bernache
# 7                  Sarah Cutler
# 8                      Adam Lee
# 9                     Eric Byrd
# 10                 Kelly Booker
# 11                 Nancy Harris
# 12  Maria Mackie, Helen Sourlis
#
#                                    Email Address: Phone Number:  \
# 0                             kirstinsd@gmail.com    7346492987
# 1                            ktolbertmd@gmail.com  301-613-3496
# 2                          healingfls@verizon.net   13013950486
# 3                           hays.donald@gmail.com  270-320-2950
# 4                               alanhew@gmail.com    3014047519
# 5                     jacqueline.mathey@gmail.com    2028180025
# 6                            bernacrock@gmail.com  301-452-6220
# 7                               Skateri@yahoo.com    3014059040
# 8                            mradamclee@gmail.com    3014585128
# 9                               ebyrd@outlook.com  301.613.4234
# 10                              kellztx@gmail.com    5126586854
# 11                         Nlharris1214@gmail.com  301-385-3375
# 12  mariamackie1985@gmail.com; hvsisa@verizon.net  240-472-0681
#
#                   Address: Preferred Contact Consultation date  \
# 0          5121 Kenesaw St             Email        2023-02-28
# 1        4908 Hollywood Rd             Email        2023-03-01
# 2         4822 Erie Street             Phone        2023-03-01
# 3         5017 Laguna Road               NaN        2023-02-27
# 4      9118 Autoville Dr.              Email        2023-02-28
# 5            8302 49TH AVE             Email        2023-03-01
# 6          4614 Amherst Rd             email        2023-03-02
# 7    7207 Rhode Island Ave             Email        2023-03-02
# 8        5911 Bryn Mawr Rd             Email        2023-03-02
# 9   9116 Saint Andrews Pl              Phone        2023-03-02
# 10       9237 Limestone Pl             Email        2023-03-03
# 11    9259 Limestone Place             Email        2023-03-01
# 12        9209 Davidson St             email        2023-02-28
#
#     Casey Trees date planted  City inspection date      Species planted  \
# 0                        NaN                   NaN  A.Hornbeam, Wil Oak
# 1                        NaN                   NaN      (2) Willow Oaks
# 2                        NaN                   NaN          S. Magnolia
# 3                        NaN                   NaN          S. Magnolia
# 4                        NaN                   NaN      Am. Witch Hazel
# 5                        NaN                   NaN          Baldcypress
# 6                        NaN                   NaN              Catalpa
# 7                        NaN                   NaN         Am. Hornbeam
# 8                        NaN                   NaN          S. Magnolia
# 9                        NaN                   NaN            Am. Holly
# 10                       NaN                   NaN          S. Magnolia
# 11                       NaN                   NaN          S. Magnolia
# 12                       NaN                   NaN         Honey Locust
#
#    Notes (Casey Trees)
# 0                match
# 1               no map
# 2                match
# 3                match
# 4                match
# 5                match
# 6                match
# 7                match
# 8                match
# 9                match
# 10         WITCH HAZEL
# 11               match
# 12               match
